# %% [markdown]
# <a href="https://www.kaggle.com/code/ryancardwell/goldenorcav6?scriptVersionId=272163748" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
